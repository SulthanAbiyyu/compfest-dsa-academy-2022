# %%
# import libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')

# %%
# import data
data = pd.read_csv('covid_19_data.csv')
print(data.shape)
data.head(10)
# Out:
# (306429, 8)
#    SNo ObservationDate Province/State  Country/Region      Last Update  \
# 0    1      01/22/2020          Anhui  Mainland China  1/22/2020 17:00
# 1    2      01/22/2020        Beijing  Mainland China  1/22/2020 17:00
# 2    3      01/22/2020      Chongqing  Mainland China  1/22/2020 17:00
# 3    4      01/22/2020         Fujian  Mainland China  1/22/2020 17:00
# 4    5      01/22/2020          Gansu  Mainland China  1/22/2020 17:00
# 5    6      01/22/2020      Guangdong  Mainland China  1/22/2020 17:00
# 6    7      01/22/2020        Guangxi  Mainland China  1/22/2020 17:00
# 7    8      01/22/2020        Guizhou  Mainland China  1/22/2020 17:00
# 8    9      01/22/2020         Hainan  Mainland China  1/22/2020 17:00
# 9   10      01/22/2020          Hebei  Mainland China  1/22/2020 17:00
#
#    Confirmed  Deaths  Recovered
# 0        1.0     0.0        0.0
# 1       14.0     0.0        0.0
# 2        6.0     0.0        0.0
# 3        1.0     0.0        0.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306429 entries, 0 to 306428
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   SNo              306429 non-null  int64
#  1   ObservationDate  306429 non-null  object
#  2   Province/State   228329 non-null  object
#  3   Country/Region   306429 non-null  object
#  4   Last Update      306429 non-null  object
#  5   Confirmed        306429 non-null  float64
#  6   Deaths           306429 non-null  float64
#  7   Recovered        306429 non-null  float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 18.7+ MB

# %%
# check for missing values
data.isna().sum()
# Out:
# SNo                    0
# ObservationDate        0
# Province/State     78100
# Country/Region         0
# Last Update            0
# Confirmed              0
# Deaths                 0
# Recovered              0
# dtype: int64

# %% [markdown]
# EDA Univariate Analysis

# %%
data['Country/Region'].nunique() # there are 229 countries in data set
# Out:
# 229

# %%
data['Province/State'].nunique() # there are 737 provinces in data set
# Out:
# 737

# %%
data.ObservationDate = pd.to_datetime(data.ObservationDate)

# %%
sns.countplot(data.ObservationDate.dt.year)
# Out:
# c:\Users\alrav\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ObservationDate', ylabel='count'>

# %%
sns.countplot(data.ObservationDate.dt.month)
# Out:
# c:\Users\alrav\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ObservationDate', ylabel='count'>

# %%
sns.countplot(data.ObservationDate.dt.day_name())
# Out:
# c:\Users\alrav\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ObservationDate', ylabel='count'>

# %% [markdown]
# #### EDA FOR INDONESIAN

# %% [markdown]
# EDA Bivariate Analysis

# %%
data_id = data[data['Country/Region']=='Indonesia']
print(data_id.shape)
data_id.head()
# Out:
# (454, 8)
#        SNo ObservationDate Province/State Country/Region          Last Update  \
# 3114  3115      2020-03-02            NaN      Indonesia  2020-03-02T18:03:04
# 3258  3259      2020-03-03            NaN      Indonesia  2020-03-02T18:03:04
# 3421  3422      2020-03-04            NaN      Indonesia  2020-03-02T18:03:04
# 3590  3591      2020-03-05            NaN      Indonesia  2020-03-02T18:03:04
# 3760  3761      2020-03-06            NaN      Indonesia  2020-03-06T12:33:03
#
#       Confirmed  Deaths  Recovered
# 3114        2.0     0.0        0.0
# 3258        2.0     0.0        0.0
# 3421        2.0     0.0        0.0
# 3590        2.0     0.0        0.0
# 3760        4.0     0.0        0.0

# %%
data_id.Confirmed.describe()
# Out:
# count    4.540000e+02
# mean     5.841102e+05
# std      6.046486e+05
# min      2.000000e+00
# 25%      4.817425e+04
# 50%      3.469545e+05
# 75%      1.131917e+06
# max      1.809926e+06
# Name: Confirmed, dtype: float64

# %%
sns.lineplot(x='ObservationDate', y='Confirmed', data=data_id)
# Out:
# <AxesSubplot:xlabel='ObservationDate', ylabel='Confirmed'>

# %%
sns.lineplot(x='ObservationDate', y='Deaths', data=data_id)
# Out:
# <AxesSubplot:xlabel='ObservationDate', ylabel='Deaths'>

# %%
sns.lineplot(x='ObservationDate', y='Recovered', data=data_id)
# Out:
# <AxesSubplot:xlabel='ObservationDate', ylabel='Recovered'>

# %%
data_global_mobility = pd.read_csv('Global_Mobility_Report.csv')
# Out:
# C:\Users\alrav\AppData\Local\Temp\ipykernel_13536\2513564021.py:1: DtypeWarning: Columns (3,4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_global_mobility = pd.read_csv('Global_Mobility_Report.csv')
