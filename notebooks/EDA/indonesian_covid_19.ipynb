# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
plt.style.use('fivethirtyeight')

# %%
df = pd.read_csv('../../data/covid-dunia/raw/covid_19_data.csv')
df.ObservationDate = pd.to_datetime(df.ObservationDate)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# g:\Other computers\My Computer\TIF UB\2. Lomba\DSA COMPFEST - 2022\notebooks\EDA\indonesian_covid_19.ipynb Cell 2' in <module>
#       <a href='vscode-notebook-cell:/g%3A/Other%20computers/My%20Computer/TIF%20UB/2.%20Lomba/DSA%20COMPFEST%20-%202022/notebooks/EDA/indonesian_covid_19.ipynb#ch0000001?line=0'>1</a> df = pd.read_csv('../../data/covid-dunia/raw/covid_19_data.csv')
# ----> <a href='vscode-notebook-cell:/g%3A/Other%20computers/My%20Computer/TIF%20UB/2.%20Lomba/DSA%20COMPFEST%20-%202022/notebooks/EDA/indonesian_covid_19.ipynb#ch0000001?line=1'>2</a> df.ObservationDate = pd.to_datetime(df.ObservationDate)
#
# File E:\Users\Asus\AppData\Roaming\Python\Python38\site-packages\pandas\core\generic.py:5487, in NDFrame.__getattr__(self, name)
#    5480 if (
#    5481     name not in self._internal_names_set
# ...

# %%
df_indo = df[df['Country/Region'] == 'Indonesia']
df_indo
# Out:
#            SNo ObservationDate Province/State Country/Region  \
# 3114      3115      2020-03-02            NaN      Indonesia
# 3258      3259      2020-03-03            NaN      Indonesia
# 3421      3422      2020-03-04            NaN      Indonesia
# 3590      3591      2020-03-05            NaN      Indonesia
# 3760      3761      2020-03-06            NaN      Indonesia
# ...        ...             ...            ...            ...
# 302674  302675      2021-05-25            NaN      Indonesia
# 303439  303440      2021-05-26            NaN      Indonesia
# 304204  304205      2021-05-27            NaN      Indonesia
# 304969  304970      2021-05-28            NaN      Indonesia
# 305734  305735      2021-05-29            NaN      Indonesia
#
#                 Last Update  Confirmed   Deaths  Recovered
# 3114    2020-03-02T18:03:04        2.0      0.0        0.0
# 3258    2020-03-02T18:03:04        2.0      0.0        0.0
# ...

# %%
df_indo['Province/State'].unique()
# Out:
# array([nan], dtype=object)

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=df_indo.ObservationDate, y=df_indo.Confirmed, name='Confirmed',fill='tozeroy',fillcolor='rgba(0, 0, 255, .3)'))
fig.add_trace(go.Scatter(x=df_indo.ObservationDate, y=df_indo.Deaths, name='Deaths', fill='tozeroy',fillcolor='rgba(255, 0, 0, 1)'))
fig.add_trace(go.Scatter(x=df_indo.ObservationDate, y=df_indo.Recovered, name='Recovered', fill='tozeroy',fillcolor='rgba(0, 255, 0, .3)'))

fig.update_layout(title='COVID-19 in Indonesia', xaxis_title='Date', yaxis_title='Number of Cases',)

# %%
fig = px.histogram(df_indo, x="ObservationDate", y=["Confirmed", "Recovered","Deaths"], title="Covid-19 in Indonesia",barmode='overlay',color_discrete_sequence=['Blue','Green','Red'])
fig.show()

# %%
df_indo['Percentage_Deaths'] = df_indo.Deaths/df_indo.Confirmed*100
df_indo['Percentage_Recovered'] = df_indo.Recovered/df_indo.Confirmed*100
# Out:
# C:\Users\alrav\AppData\Local\Temp\ipykernel_2712\1779413931.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\alrav\AppData\Local\Temp\ipykernel_2712\1779413931.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_indo
# Out:
#            SNo ObservationDate Province/State Country/Region  \
# 3114      3115      2020-03-02            NaN      Indonesia
# 3258      3259      2020-03-03            NaN      Indonesia
# 3421      3422      2020-03-04            NaN      Indonesia
# 3590      3591      2020-03-05            NaN      Indonesia
# 3760      3761      2020-03-06            NaN      Indonesia
# ...        ...             ...            ...            ...
# 302674  302675      2021-05-25            NaN      Indonesia
# 303439  303440      2021-05-26            NaN      Indonesia
# 304204  304205      2021-05-27            NaN      Indonesia
# 304969  304970      2021-05-28            NaN      Indonesia
# 305734  305735      2021-05-29            NaN      Indonesia
#
#                 Last Update  Confirmed   Deaths  Recovered  Percentage_Deaths  \
# 3114    2020-03-02T18:03:04        2.0      0.0        0.0           0.000000
# ...

# %%
fig = px.histogram(df_indo, x="ObservationDate", y=["Percentage_Deaths", "Percentage_Recovered"], title="Percentage Deaths vs Recovered",color_discrete_sequence=['Red','Green'],text_auto=True,histfunc='avg')
fig.update_traces(textposition='inside',textfont_size=10)
fig.update_layout(
    title='Percentage Recovered vs Deaths',
    # xaxis_tickfont_size=14,
    uniformtext_minsize=10, uniformtext_mode=False,
    yaxis=dict(
        title='Percentage',
        titlefont_size=16,
        tickfont_size=14,
    ),
    legend=dict(
        x=0,
        y=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'
    ),
    barmode='stack',
    bargap=0.15, # gap between bars of adjacent location coordinates.
    bargroupgap=0.1 # gap between bars of the same location coordinate.
)
fig.show()

# %%
# load the data
df_mobility = pd.read_csv('2020_ID_Region_Mobility_Report.csv')
print(df_mobility.shape)
df_mobility.head()
# Out:
# (11235, 15)
#   country_region_code country_region sub_region_1  sub_region_2  metro_area  \
# 0                  ID      Indonesia          NaN           NaN         NaN
# 1                  ID      Indonesia          NaN           NaN         NaN
# 2                  ID      Indonesia          NaN           NaN         NaN
# 3                  ID      Indonesia          NaN           NaN         NaN
# 4                  ID      Indonesia          NaN           NaN         NaN
#
#   iso_3166_2_code  census_fips_code                     place_id        date  \
# 0             NaN               NaN  ChIJtwRkSdcHTCwRhfStG-dNe-M  2020-02-15
# 1             NaN               NaN  ChIJtwRkSdcHTCwRhfStG-dNe-M  2020-02-16
# 2             NaN               NaN  ChIJtwRkSdcHTCwRhfStG-dNe-M  2020-02-17
# 3             NaN               NaN  ChIJtwRkSdcHTCwRhfStG-dNe-M  2020-02-18
# 4             NaN               NaN  ChIJtwRkSdcHTCwRhfStG-dNe-M  2020-02-19
#
# ...

# %%
df_mobility.isna().sum()
# Out:
# country_region_code                                       0
# country_region                                            0
# sub_region_1                                            321
# sub_region_2                                          11235
# metro_area                                            11235
# iso_3166_2_code                                         321
# census_fips_code                                      11235
# place_id                                                  0
# date                                                      0
# retail_and_recreation_percent_change_from_baseline       50
# grocery_and_pharmacy_percent_change_from_baseline        99
# parks_percent_change_from_baseline                      118
# transit_stations_percent_change_from_baseline           391
# workplaces_percent_change_from_baseline                   0
# residential_percent_change_from_baseline                  0
# dtype: int64

# %%
df_mobility.date = pd.to_datetime(df_mobility.date)
df_mobility.columns
# Out:
# Index(['country_region_code', 'country_region', 'sub_region_1', 'sub_region_2',
#        'metro_area', 'iso_3166_2_code', 'census_fips_code', 'place_id', 'date',
#        'retail_and_recreation_percent_change_from_baseline',
#        'grocery_and_pharmacy_percent_change_from_baseline',
#        'parks_percent_change_from_baseline',
#        'transit_stations_percent_change_from_baseline',
#        'workplaces_percent_change_from_baseline',
#        'residential_percent_change_from_baseline'],
#       dtype='object')

# %%
# function for plot
def plot_this(data,y):
    tes = data[['date',y]]
    tes = tes.groupby('date').mean()
    tes['naik'] = np.where(tes[y]>0,tes[y],0)
    tes['turun'] = np.where(tes[y]<0,tes[y],0)
    fig = go.Figure()
    fig.add_trace(go.Scatter(x=tes.index, y=tes.turun*10,fill='tozeroy',fillcolor='rgba(255, 0, 0,0.7)',line = dict(color='rgba(255,0,0,0.7)')))
    fig.add_trace(go.Scatter(x=tes.index, y=tes.naik*10,fill='tozeroy',fillcolor='rgba(33, 168, 96,0.7)',line = dict(color='rgba(33,168,96,0.7)')))
    fig.update_layout(
        title=' '.join(y.split('_')),
        showlegend=False,
        yaxis= {'tickformat': ',.0%'}
    )
    fig.show()

# %%
plot_this(df_mobility,'retail_and_recreation_percent_change_from_baseline')

# %%
plot_this(df_mobility,'grocery_and_pharmacy_percent_change_from_baseline')

# %%
plot_this(df_mobility,'parks_percent_change_from_baseline')

# %%
plot_this(df_mobility,'transit_stations_percent_change_from_baseline')

# %%
plot_this(df_mobility,'workplaces_percent_change_from_baseline')

# %%
plot_this(df_mobility,'residential_percent_change_from_baseline')

# %%
df_mobility.sub_region_1.value_counts() # there are 34 province and each province has 321 values.
# Out:
# Aceh                            321
# South Sulawesi                  321
# North Sumatra                   321
# Papua                           321
# Riau                            321
# Riau Islands                    321
# South East Sulawesi             321
# South Kalimantan                321
# South Sumatra                   321
# Bali                            321
# Special Region of Yogyakarta    321
# West Java                       321
# West Kalimantan                 321
# West Nusa Tenggara              321
# West Papua                      321
# West Sulawesi                   321
# North Sulawesi                  321
# North Maluku                    321
# North Kalimantan                321
# Maluku                          321
# Lampung                         321
# Jambi                           321
# Jakarta                         321
# Gorontalo                       321
# East Nusa Tenggara              321
# East Kalimantan                 321
# ...

# %%
df_mobility.groupby('sub_region_1').mean().iloc[:,3:]
# Out:
#                               retail_and_recreation_percent_change_from_baseline  \
# sub_region_1
# Aceh                                                                  -9.676012
# Bali                                                                 -34.137072
# Bangka Belitung Islands                                              -20.177570
# Banten                                                               -16.794393
# Bengkulu                                                              -8.707165
# Central Java                                                         -11.037383
# Central Kalimantan                                                   -17.277259
# Central Sulawesi                                                     -11.476636
# East Java                                                            -15.373832
# East Kalimantan                                                      -18.894081
# ...

# %%
df_mobility[df_mobility.sub_region_1 == 'Jakarta']
# Out:
#      country_region_code country_region sub_region_1  sub_region_2  \
# 4173                  ID      Indonesia      Jakarta           NaN
# 4174                  ID      Indonesia      Jakarta           NaN
# 4175                  ID      Indonesia      Jakarta           NaN
# 4176                  ID      Indonesia      Jakarta           NaN
# 4177                  ID      Indonesia      Jakarta           NaN
# ...                  ...            ...          ...           ...
# 4489                  ID      Indonesia      Jakarta           NaN
# 4490                  ID      Indonesia      Jakarta           NaN
# 4491                  ID      Indonesia      Jakarta           NaN
# 4492                  ID      Indonesia      Jakarta           NaN
# 4493                  ID      Indonesia      Jakarta           NaN
#
#       metro_area iso_3166_2_code  census_fips_code  \
# 4173         NaN           ID-JK               NaN
# 4174         NaN           ID-JK               NaN
# ...
