# %%
import pandas as pd

# %%
# Load the data
covid_19_data = pd.read_csv('covid_19_data.csv')
covid_19_data.head()
# Out:
#    SNo ObservationDate Province/State  Country/Region      Last Update  \
# 0    1      01/22/2020          Anhui  Mainland China  1/22/2020 17:00
# 1    2      01/22/2020        Beijing  Mainland China  1/22/2020 17:00
# 2    3      01/22/2020      Chongqing  Mainland China  1/22/2020 17:00
# 3    4      01/22/2020         Fujian  Mainland China  1/22/2020 17:00
# 4    5      01/22/2020          Gansu  Mainland China  1/22/2020 17:00
#
#    Confirmed  Deaths  Recovered
# 0        1.0     0.0        0.0
# 1       14.0     0.0        0.0
# 2        6.0     0.0        0.0
# 3        1.0     0.0        0.0
# 4        0.0     0.0        0.0

# %%
# load the data2
time_series_covid_19_confirmed_US = pd.read_csv('time_series_covid_19_confirmed_US.csv')
print(time_series_covid_19_confirmed_US.shape)
time_series_covid_19_confirmed_US.head()
# Out:
# (3342, 505)
#         UID iso2 iso3  code3    FIPS   Admin2 Province_State Country_Region  \
# 0  84001001   US  USA    840  1001.0  Autauga        Alabama             US
# 1  84001003   US  USA    840  1003.0  Baldwin        Alabama             US
# 2  84001005   US  USA    840  1005.0  Barbour        Alabama             US
# 3  84001007   US  USA    840  1007.0     Bibb        Alabama             US
# 4  84001009   US  USA    840  1009.0   Blount        Alabama             US
#
#          Lat      Long_  ... 5/20/21  5/21/21  5/22/21  5/23/21  5/24/21  \
# 0  32.539527 -86.644082  ...    7049     7106     7113     7118     7118
# 1  30.727750 -87.722071  ...   21489    21511    21535    21546    21554
# 2  31.868263 -85.387129  ...    2326     2327     2328     2328     2328
# 3  32.996421 -87.125115  ...    2656     2657     2656     2658     2659
# 4  33.982109 -86.567906  ...    6816     6826     6829     6832     6832
#
#    5/25/21  5/26/21  5/27/21  5/28/21  5/29/21
# ...

# %%
# load the data3
time_series_covid_19_confirmed = pd.read_csv('time_series_covid_19_confirmed.csv')
print(time_series_covid_19_confirmed.shape)
time_series_covid_19_confirmed.head()
# Out:
# (276, 498)
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  5/20/21  5/21/21  5/22/21  \
# 0        0        0        0        0  ...    64575    65080    65486
# 1        0        0        0        0  ...   132118   132153   132176
# 2        0        0        0        0  ...   126156   126434   126651
# 3        0        0        0        0  ...    13569    13569    13569
# 4        0        0        0        0  ...    31661    31909    32149
#
#    5/23/21  5/24/21  5/25/21  5/26/21  5/27/21  5/28/21  5/29/21
# ...

# %%
# load the data 5
time_series_covid_19_deaths_US = pd.read_csv('time_series_covid_19_deaths_US.csv')
print(time_series_covid_19_deaths_US.shape)
time_series_covid_19_deaths_US.head()
# Out:
# (3342, 506)
#         UID iso2 iso3  code3    FIPS   Admin2 Province_State Country_Region  \
# 0  84001001   US  USA    840  1001.0  Autauga        Alabama             US
# 1  84001003   US  USA    840  1003.0  Baldwin        Alabama             US
# 2  84001005   US  USA    840  1005.0  Barbour        Alabama             US
# 3  84001007   US  USA    840  1007.0     Bibb        Alabama             US
# 4  84001009   US  USA    840  1009.0   Blount        Alabama             US
#
#          Lat      Long_  ... 5/20/21  5/21/21  5/22/21  5/23/21  5/24/21  \
# 0  32.539527 -86.644082  ...     109      109      110      110      110
# 1  30.727750 -87.722071  ...     310      310      310      310      310
# 2  31.868263 -85.387129  ...      58       58       58       58       58
# 3  32.996421 -87.125115  ...      64       64       64       64       64
# 4  33.982109 -86.567906  ...     139      139      139      139      139
#
#    5/25/21  5/26/21  5/27/21  5/28/21  5/29/21
# ...

# %%
# load the data 6
time_series_covid_19_deaths = pd.read_csv('time_series_covid_19_deaths.csv')
print(time_series_covid_19_deaths.shape)
time_series_covid_19_deaths.head()
# Out:
# (276, 498)
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  5/20/21  5/21/21  5/22/21  \
# 0        0        0        0        0  ...     2772     2782     2792
# 1        0        0        0        0  ...     2440     2441     2442
# 2        0        0        0        0  ...     3401     3405     3411
# 3        0        0        0        0  ...      127      127      127
# 4        0        0        0        0  ...      704      709      715
#
#    5/23/21  5/24/21  5/25/21  5/26/21  5/27/21  5/28/21  5/29/21
# ...

# %%
# load the data 7
time_series_covid_19_recovered = pd.read_csv('time_series_covid_19_recovered.csv')
print(time_series_covid_19_recovered.shape)
time_series_covid_19_recovered.head()
# Out:
# (261, 498)
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  5/20/21  5/21/21  5/22/21  \
# 0        0        0        0        0  ...    55687    55790    55889
# 1        0        0        0        0  ...   127869   128425   128601
# 2        0        0        0        0  ...    87902    88066    88208
# 3        0        0        0        0  ...    13234    13234    13234
# 4        0        0        0        0  ...    26483    26513    26775
#
#    5/23/21  5/24/21  5/25/21  5/26/21  5/27/21  5/28/21  5/29/21
# ...

# %%
time_series_covid_19_recovered[time_series_covid_19_recovered['Country/Region'] == 'Indonesia'].head()
# Out:
#     Province/State Country/Region     Lat      Long  1/22/20  1/23/20  \
# 133            NaN      Indonesia -0.7893  113.9213        0        0
#
#      1/24/20  1/25/20  1/26/20  1/27/20  ...  5/20/21  5/21/21  5/22/21  \
# 133        0        0        0        0  ...  1621572  1626142  1629495
#
#      5/23/21  5/24/21  5/25/21  5/26/21  5/27/21  5/28/21  5/29/21
# 133  1633045  1638279  1642074  1645263  1649187  1654557  1659974
#
# [1 rows x 498 columns]

# %%
# load the data
mobility_reprot_id = pd.read_csv('2020_ID_Region_Mobility_Report.csv')
print(mobility_reprot_id.shape)
mobility_reprot_id.head()
# Out:
# (11235, 15)
#   country_region_code country_region sub_region_1  sub_region_2  metro_area  \
# 0                  ID      Indonesia          NaN           NaN         NaN
# 1                  ID      Indonesia          NaN           NaN         NaN
# 2                  ID      Indonesia          NaN           NaN         NaN
# 3                  ID      Indonesia          NaN           NaN         NaN
# 4                  ID      Indonesia          NaN           NaN         NaN
#
#   iso_3166_2_code  census_fips_code                     place_id        date  \
# 0             NaN               NaN  ChIJtwRkSdcHTCwRhfStG-dNe-M  2020-02-15
# 1             NaN               NaN  ChIJtwRkSdcHTCwRhfStG-dNe-M  2020-02-16
# 2             NaN               NaN  ChIJtwRkSdcHTCwRhfStG-dNe-M  2020-02-17
# 3             NaN               NaN  ChIJtwRkSdcHTCwRhfStG-dNe-M  2020-02-18
# 4             NaN               NaN  ChIJtwRkSdcHTCwRhfStG-dNe-M  2020-02-19
#
# ...

# %%
mobility_reprot_id.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11235 entries, 0 to 11234
# Data columns (total 15 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   country_region_code                                 11235 non-null  object
#  1   country_region                                      11235 non-null  object
#  2   sub_region_1                                        10914 non-null  object
#  3   sub_region_2                                        0 non-null      float64
#  4   metro_area                                          0 non-null      float64
#  5   iso_3166_2_code                                     10914 non-null  object
#  6   census_fips_code                                    0 non-null      float64
#  7   place_id                                            11235 non-null  object
# ...

# %%
mobility_reprot_id.isna().sum()
# Out:
# country_region_code                                       0
# country_region                                            0
# sub_region_1                                            321
# sub_region_2                                          11235
# metro_area                                            11235
# iso_3166_2_code                                         321
# census_fips_code                                      11235
# place_id                                                  0
# date                                                      0
# retail_and_recreation_percent_change_from_baseline       50
# grocery_and_pharmacy_percent_change_from_baseline        99
# parks_percent_change_from_baseline                      118
# transit_stations_percent_change_from_baseline           391
# workplaces_percent_change_from_baseline                   0
# residential_percent_change_from_baseline                  0
# dtype: int64
